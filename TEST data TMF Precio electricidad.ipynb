# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns = None

# %%
# !pwd
# Out:
# /home/dsc/CarpetaCompartida/TFM

# %%
path_2013 = "/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/PFMDIASM_TOD_2013"

# %%
jan2013 = pd.read_excel(path_2013 + "01.2/PFMDIASM_TOD_20130101_20130131.xls", 
                      dtype= str,parse_dates= True, engine= None, header = 3)

jan2013.head()
# Out:
#               Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0  01/01/13 Martes               575111.397                    33.31
# 1  02/01/13 Miércoles            681911.324                    50.75
# 2  03/01/13 Jueves               724426.458                    57.07
# 3  04/01/13 Viernes              717141.532                    61.31
# 4  05/01/13 Sábado                682149.96                    58.11
#
#   Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# 0                          0.43                 6.08                  2.49
# 1                          0.12                 3.15                  3.18
# 2                         -0.13                 1.92                  3.47
# 3                         -0.08                 1.71                   2.4
# 4                          0.14                 1.29                  1.43
#
#   Garantía potencia \nPagos capacidad\n€/MWh Total\n€/MWh
# ...

# %%
jan2013
# Out:
#                Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0   01/01/13 Martes               575111.397                    33.31
# 1   02/01/13 Miércoles            681911.324                    50.75
# 2   03/01/13 Jueves               724426.458                    57.07
# 3   04/01/13 Viernes              717141.532                    61.31
# 4   05/01/13 Sábado                682149.96                    58.11
# 5   06/01/13 Domingo              647854.785                    58.01
# 6   07/01/13 Lunes                707896.584                    63.42
# 7   08/01/13 Martes               792239.818                       69
# 8   09/01/13 Miércoles            813192.864                    67.43
# 9   10/01/13 Jueves               821426.583                    66.12
# 10  11/01/13 Viernes              798185.741                    72.41
# 11  12/01/13 Sábado               740278.669                       54
# ...

# %%
jan2013.dtypes
# Out:
# Periodo                                       object
# Energía\n final \nMWh                         object
# Mercado \ndiario \n€/MWh                      object
# Mercado \nintradiario \n€/MWh                 object
# Restricciones\n€/MWh                          object
# Procesos \nOS \n€/MWh                         object
# Garantía potencia \nPagos capacidad\n€/MWh    object
# Total\n€/MWh                                  object
# dtype: object

# %%
jan2013[["Date", "Day"]] = jan2013.Periodo.str.split(expand= True)

# %%
jan2013
# Out:
#                Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0   01/01/13 Martes               575111.397                    33.31
# 1   02/01/13 Miércoles            681911.324                    50.75
# 2   03/01/13 Jueves               724426.458                    57.07
# 3   04/01/13 Viernes              717141.532                    61.31
# 4   05/01/13 Sábado                682149.96                    58.11
# 5   06/01/13 Domingo              647854.785                    58.01
# 6   07/01/13 Lunes                707896.584                    63.42
# 7   08/01/13 Martes               792239.818                       69
# 8   09/01/13 Miércoles            813192.864                    67.43
# 9   10/01/13 Jueves               821426.583                    66.12
# 10  11/01/13 Viernes              798185.741                    72.41
# 11  12/01/13 Sábado               740278.669                       54
# ...

# %%
jan2013.dtypes
# Out:
# Periodo                                       object
# Energía\n final \nMWh                         object
# Mercado \ndiario \n€/MWh                      object
# Mercado \nintradiario \n€/MWh                 object
# Restricciones\n€/MWh                          object
# Procesos \nOS \n€/MWh                         object
# Garantía potencia \nPagos capacidad\n€/MWh    object
# Total\n€/MWh                                  object
# Date                                          object
# Day                                           object
# dtype: object

# %%
jan2013["Date"] = pd.to_datetime(jan2013["Date"])

# %%
jan2013.dtypes
# Out:
# Periodo                                               object
# Energía\n final \nMWh                                 object
# Mercado \ndiario \n€/MWh                              object
# Mercado \nintradiario \n€/MWh                         object
# Restricciones\n€/MWh                                  object
# Procesos \nOS \n€/MWh                                 object
# Garantía potencia \nPagos capacidad\n€/MWh            object
# Total\n€/MWh                                          object
# Date                                          datetime64[ns]
# Day                                                   object
# dtype: object

# %%
jan2013.head()
# Out:
#               Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0  01/01/13 Martes               575111.397                    33.31
# 1  02/01/13 Miércoles            681911.324                    50.75
# 2  03/01/13 Jueves               724426.458                    57.07
# 3  04/01/13 Viernes              717141.532                    61.31
# 4  05/01/13 Sábado                682149.96                    58.11
#
#   Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# 0                          0.43                 6.08                  2.49
# 1                          0.12                 3.15                  3.18
# 2                         -0.13                 1.92                  3.47
# 3                         -0.08                 1.71                   2.4
# 4                          0.14                 1.29                  1.43
#
#   Garantía potencia \nPagos capacidad\n€/MWh Total\n€/MWh       Date  \
# ...

# %%
import glob

# %%
data2013_import = glob.glob("/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_2013*xls")
print(data2013_import)
# Out:
# ['/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130101_20130131.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130201_20130228.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130301_20130331.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130401_20130430.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130501_20130531.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130601_20130630.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130701_20130731.xls', '/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_20130801_20130831.xls', '/home/dsc/Ca
# ...

# %%
#This doesn't work because it returns a list, not a Dataframe

data2013 = []

for filename in data2013_import:
    data= pd.read_excel(filename, dtype= str,parse_dates= True, engine= None, header = 3)
    data2013.append(data)
    
data2013

pd.concat(data2013, ignore_index= True)
# Out:
#                 Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0    01/01/13 Martes               575111.397                    33.31
# 1    02/01/13 Miércoles            681911.324                    50.75
# 2    03/01/13 Jueves               724426.458                    57.07
# 3    04/01/13 Viernes              717141.532                    61.31
# 4    05/01/13 Sábado                682149.96                    58.11
# ..                  ...                   ...                      ...
# 360  27/12/13 Viernes              663171.045                    15.39
# 361  28/12/13 Sábado                672714.85                    23.98
# 362  29/12/13 Domingo              634045.486                    42.83
# 363  30/12/13 Lunes                634951.745                    47.39
# 364  31/12/13 Martes               606765.004                    25.26
#
#     Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# ...

# %%
type(data2013)
# Out:
# list

# %%
#Using glob.iglob() it returns an iterator that I can easily convert into a pandas Dataframe
data2013_import = glob.iglob("/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Definitivo_2013/2013/PFMDIASM_TOD_2013*xls")
print(data2013_import)

dataframes = (pd.read_excel(excel, dtype= str,parse_dates= True, engine= None, header = 3) for excel in data2013_import)

data2013  = pd.concat(dataframes, ignore_index= True)
# Out:
# <generator object _iglob at 0x7fd8afe4f970>

# %%
data2013
# Out:
#                 Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0    01/01/13 Martes               575111.397                    33.31
# 1    02/01/13 Miércoles            681911.324                    50.75
# 2    03/01/13 Jueves               724426.458                    57.07
# 3    04/01/13 Viernes              717141.532                    61.31
# 4    05/01/13 Sábado                682149.96                    58.11
# ..                  ...                   ...                      ...
# 360  27/12/13 Viernes              663171.045                    15.39
# 361  28/12/13 Sábado                672714.85                    23.98
# 362  29/12/13 Domingo              634045.486                    42.83
# 363  30/12/13 Lunes                634951.745                    47.39
# 364  31/12/13 Martes               606765.004                    25.26
#
#     Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# ...

# %%
type(data2013)
# Out:
# pandas.core.frame.DataFrame

# %%
data2013[["Date", "Day"]] = data2013.Periodo.str.split(expand= True)

# %%
data2013.head()
# Out:
#               Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0  01/01/13 Martes               575111.397                    33.31
# 1  02/01/13 Miércoles            681911.324                    50.75
# 2  03/01/13 Jueves               724426.458                    57.07
# 3  04/01/13 Viernes              717141.532                    61.31
# 4  05/01/13 Sábado                682149.96                    58.11
#
#   Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# 0                          0.43                 6.08                  2.49
# 1                          0.12                 3.15                  3.18
# 2                         -0.13                 1.92                  3.47
# 3                         -0.08                 1.71                   2.4
# 4                          0.14                 1.29                  1.43
#
#   Garantía potencia \nPagos capacidad\n€/MWh Total\n€/MWh      Date        Day
# ...

# %%
data2013["Date"] = pd.to_datetime(data2013["Date"])

# %%
brent_prices = pd.read_csv("/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Datos_históricos_Futuros_petróleo_Brent.csv")
brent_prices
# Out:
#            Fecha  Último Apertura  Máximo  Mínimo     Vol.  % var.
# 0     16.07.2021   73,59    73,18   74,09   72,34  292,66K   0,16%
# 1     15.07.2021   73,47    74,50   74,59   73,19  322,33K  -1,73%
# 2     14.07.2021   74,76    76,28   76,72   73,79  376,94K  -2,26%
# 3     13.07.2021   76,49    75,25   76,60   74,93  275,91K   1,77%
# 4     12.07.2021   75,16    75,79   75,84   74,23  262,30K  -0,52%
# ...          ...     ...      ...     ...     ...      ...     ...
# 2200  08.01.2013  111,94   111,42  112,47  111,12  194,00K   0,48%
# 2201  07.01.2013  111,40   111,42  111,69  110,54  203,50K   0,08%
# 2202  04.01.2013  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 2203  03.01.2013  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 2204  02.01.2013  112,47   111,50  112,90  111,27  183,14K   1,22%
#
# [2205 rows x 7 columns]

# %%
brent_prices.dtypes
# Out:
# Fecha       object
# Último      object
# Apertura    object
# Máximo      object
# Mínimo      object
# Vol.        object
# % var.      object
# dtype: object

# %%
brent_prices["Fecha"] = pd.to_datetime(brent_prices["Fecha"])

# %%
#Column "Vol." is the number of contracts that were sold that day
brent_prices
# Out:
#           Fecha  Último Apertura  Máximo  Mínimo     Vol.  % var.
# 0    2021-07-16   73,59    73,18   74,09   72,34  292,66K   0,16%
# 1    2021-07-15   73,47    74,50   74,59   73,19  322,33K  -1,73%
# 2    2021-07-14   74,76    76,28   76,72   73,79  376,94K  -2,26%
# 3    2021-07-13   76,49    75,25   76,60   74,93  275,91K   1,77%
# 4    2021-12-07   75,16    75,79   75,84   74,23  262,30K  -0,52%
# ...         ...     ...      ...     ...     ...      ...     ...
# 2200 2013-08-01  111,94   111,42  112,47  111,12  194,00K   0,48%
# 2201 2013-07-01  111,40   111,42  111,69  110,54  203,50K   0,08%
# 2202 2013-04-01  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 2203 2013-03-01  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 2204 2013-02-01  112,47   111,50  112,90  111,27  183,14K   1,22%
#
# [2205 rows x 7 columns]

# %%
brent_prices.dtypes
# Out:
# Fecha       datetime64[ns]
# Último              object
# Apertura            object
# Máximo              object
# Mínimo              object
# Vol.                object
# % var.              object
# dtype: object

# %%
brent_prices.rename(columns={"Fecha":"Date"}, inplace= True)

# %%
brent_prices
# Out:
#            Date  Último Apertura  Máximo  Mínimo     Vol.  % var.
# 0    2021-07-16   73,59    73,18   74,09   72,34  292,66K   0,16%
# 1    2021-07-15   73,47    74,50   74,59   73,19  322,33K  -1,73%
# 2    2021-07-14   74,76    76,28   76,72   73,79  376,94K  -2,26%
# 3    2021-07-13   76,49    75,25   76,60   74,93  275,91K   1,77%
# 4    2021-12-07   75,16    75,79   75,84   74,23  262,30K  -0,52%
# ...         ...     ...      ...     ...     ...      ...     ...
# 2200 2013-08-01  111,94   111,42  112,47  111,12  194,00K   0,48%
# 2201 2013-07-01  111,40   111,42  111,69  110,54  203,50K   0,08%
# 2202 2013-04-01  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 2203 2013-03-01  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 2204 2013-02-01  112,47   111,50  112,90  111,27  183,14K   1,22%
#
# [2205 rows x 7 columns]

# %%
prices2013_brent = pd.merge(data2013, brent_prices, on= "Date", sort=False, indicator= True)
prices2013_brent
# Out:
#                 Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0    02/01/13 Miércoles            681911.324                    50.75
# 1    03/01/13 Jueves               724426.458                    57.07
# 2    04/01/13 Viernes              717141.532                    61.31
# 3    07/01/13 Lunes                707896.584                    63.42
# 4    08/01/13 Martes               792239.818                       69
# ..                  ...                   ...                      ...
# 253  24/12/13 Martes               627047.199                     9.63
# 254  26/12/13 Jueves               659881.358                    14.18
# 255  27/12/13 Viernes              663171.045                    15.39
# 256  30/12/13 Lunes                634951.745                    47.39
# 257  31/12/13 Martes               606765.004                    25.26
#
#     Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# ...

# %%
brent_prices["Date"]
# Out:
# 0      2021-07-16
# 1      2021-07-15
# 2      2021-07-14
# 3      2021-07-13
# 4      2021-12-07
#           ...
# 2200   2013-08-01
# 2201   2013-07-01
# 2202   2013-04-01
# 2203   2013-03-01
# 2204   2013-02-01
# Name: Date, Length: 2205, dtype: datetime64[ns]

# %%
brent_prices = brent_prices.set_index(["Date"])
brent_2013 = brent_prices.loc['2013-01-01':'2013-12-31']
print(brent_2013)
# Out:
#             Último Apertura  Máximo  Mínimo     Vol.  % var.
# Date
# 2013-12-31  110,80   111,18  111,52  110,40   84,99K  -0,37%
# 2013-12-30  111,21   112,20  112,64  110,90  111,07K  -0,86%
# 2013-12-27  112,18   111,95  112,80  111,50  126,91K   0,18%
# 2013-12-26  111,98   111,99  112,12  111,46   43,62K   0,07%
# 2013-12-24  111,90   111,61  112,06  111,42   52,16K   0,30%
# ...            ...      ...     ...     ...      ...     ...
# 2013-08-01  111,94   111,42  112,47  111,12  194,00K   0,48%
# 2013-07-01  111,40   111,42  111,69  110,54  203,50K   0,08%
# 2013-04-01  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 2013-03-01  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 2013-02-01  112,47   111,50  112,90  111,27  183,14K   1,22%
#
# [258 rows x 6 columns]

# %%
#In the brent_prices DataFrame, we're missing Saturday and Sunday prices (and bank holidays) 
#This is because the Brent Crude Futures Markets does not operate during weekends.
#So Friday prices should also be Saturday and Sunday prices.

prices2013_brent["Day"].unique()
# Out:
# array(['Miércoles', 'Jueves', 'Viernes', 'Lunes', 'Martes'], dtype=object)

# %%
date_day = data2013[["Date", "Day"]]
date_day
# Out:
#           Date        Day
# 0   2013-01-01     Martes
# 1   2013-02-01  Miércoles
# 2   2013-03-01     Jueves
# 3   2013-04-01    Viernes
# 4   2013-05-01     Sábado
# ..         ...        ...
# 360 2013-12-27    Viernes
# 361 2013-12-28     Sábado
# 362 2013-12-29    Domingo
# 363 2013-12-30      Lunes
# 364 2013-12-31     Martes
#
# [365 rows x 2 columns]

# %%
brent_prices_allweek = pd.merge(date_day, brent_prices, on= "Date", indicator = True, how= "left")
brent_prices_allweek
# Out:
#           Date        Day  Último Apertura  Máximo  Mínimo     Vol.  % var.  \
# 0   2013-01-01     Martes     NaN      NaN     NaN     NaN      NaN     NaN
# 1   2013-02-01  Miércoles  112,47   111,50  112,90  111,27  183,14K   1,22%
# 2   2013-03-01     Jueves  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 3   2013-04-01    Viernes  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 4   2013-05-01     Sábado     NaN      NaN     NaN     NaN      NaN     NaN
# ..         ...        ...     ...      ...     ...     ...      ...     ...
# 360 2013-12-27    Viernes  112,18   111,95  112,80  111,50  126,91K   0,18%
# 361 2013-12-28     Sábado     NaN      NaN     NaN     NaN      NaN     NaN
# 362 2013-12-29    Domingo     NaN      NaN     NaN     NaN      NaN     NaN
# 363 2013-12-30      Lunes  111,21   112,20  112,64  110,90  111,07K  -0,86%
# 364 2013-12-31     Martes  110,80   111,18  111,52  110,40   84,99K  -0,37%
#
#         _merge
# 0    left_only
# 1         both
# ...

# %%
#There were 107 Saturday, Sunday and bank holidays in 2013 in Spain
np.count_nonzero(brent_prices_allweek["_merge"] != "both")
# Out:
# 107

# %%
weekends_holidays_index = brent_prices_allweek[brent_prices_allweek["_merge"] != "both"].index.tolist()
weekends_holidays_index
# Out:
# [0,
#  4,
#  5,
#  11,
#  12,
#  18,
#  19,
#  25,
#  26,
#  32,
#  33,
#  39,
#  40,
#  46,
#  47,
#  53,
#  54,
#  60,
#  61,
#  67,
#  68,
#  74,
#  75,
#  81,
#  82,
#  87,
#  88,
#  89,
#  95,
#  96,
#  102,
#  103,
#  109,
#  110,
#  116,
#  117,
#  123,
#  124,
#  130,
#  131,
#  137,
#  138,
#  144,
#  145,
#  151,
#  152,
#  158,
#  159,
#  165,
#  166,
#  172,
#  173,
#  179,
#  180,
#  186,
#  187,
#  193,
#  194,
#  200,
#  201,
#  207,
#  208,
#  214,
#  215,
#  221,
#  222,
#  228,
#  229,
#  235,
#  236,
#  242,
#  243,
#  249,
#  250,
#  256,
#  257,
#  263,
#  264,
#  270,
#  271,
#  277,
#  278,
#  284,
#  285,
#  291,
#  292,
#  298,
#  299,
#  305,
#  306,
#  312,
#  313,
#  319,
#  320,
#  326,
#  327,
#  333,
#  334,
#  340,
#  341,
#  347,
#  348,
#  354,
#  355,
#  358,
#  361,
#  362]

# %%
brent_prices_allweek = brent_prices_allweek.fillna(method= "ffill")
brent_prices_allweek
# Out:
#           Date        Day  Último Apertura  Máximo  Mínimo     Vol.  % var.  \
# 0   2013-01-01     Martes     NaN      NaN     NaN     NaN      NaN     NaN
# 1   2013-02-01  Miércoles  112,47   111,50  112,90  111,27  183,14K   1,22%
# 2   2013-03-01     Jueves  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 3   2013-04-01    Viernes  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 4   2013-05-01     Sábado  111,31   111,72  111,78  110,38  191,33K  -0,74%
# ..         ...        ...     ...      ...     ...     ...      ...     ...
# 360 2013-12-27    Viernes  112,18   111,95  112,80  111,50  126,91K   0,18%
# 361 2013-12-28     Sábado  112,18   111,95  112,80  111,50  126,91K   0,18%
# 362 2013-12-29    Domingo  112,18   111,95  112,80  111,50  126,91K   0,18%
# 363 2013-12-30      Lunes  111,21   112,20  112,64  110,90  111,07K  -0,86%
# 364 2013-12-31     Martes  110,80   111,18  111,52  110,40   84,99K  -0,37%
#
#         _merge
# 0    left_only
# 1         both
# ...

# %%
#The 1st of January of 2013 still has NaN values, but I don't have historical data before that.
#Therefore, I'll drop that row
brent_prices_allweek.isna().sum()
# Out:
# Date        0
# Day         0
# Último      1
# Apertura    1
# Máximo      1
# Mínimo      1
# Vol.        1
# % var.      1
# _merge      0
# dtype: int64

# %%
brent_prices_allweek = brent_prices_allweek.dropna()
brent_prices_allweek
# Out:
#           Date        Day  Último Apertura  Máximo  Mínimo     Vol.  % var.  \
# 1   2013-02-01  Miércoles  112,47   111,50  112,90  111,27  183,14K   1,22%
# 2   2013-03-01     Jueves  112,14   112,20  112,42  111,63  190,29K  -0,29%
# 3   2013-04-01    Viernes  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 4   2013-05-01     Sábado  111,31   111,72  111,78  110,38  191,33K  -0,74%
# 5   2013-06-01    Domingo  111,31   111,72  111,78  110,38  191,33K  -0,74%
# ..         ...        ...     ...      ...     ...     ...      ...     ...
# 360 2013-12-27    Viernes  112,18   111,95  112,80  111,50  126,91K   0,18%
# 361 2013-12-28     Sábado  112,18   111,95  112,80  111,50  126,91K   0,18%
# 362 2013-12-29    Domingo  112,18   111,95  112,80  111,50  126,91K   0,18%
# 363 2013-12-30      Lunes  111,21   112,20  112,64  110,90  111,07K  -0,86%
# 364 2013-12-31     Martes  110,80   111,18  111,52  110,40   84,99K  -0,37%
#
#         _merge
# 1         both
# 2         both
# ...

# %%
prices2013_brent = pd.merge(data2013, brent_prices_allweek, on= "Date", sort=False)
prices2013_brent
# Out:
#                 Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0    02/01/13 Miércoles            681911.324                    50.75
# 1    03/01/13 Jueves               724426.458                    57.07
# 2    04/01/13 Viernes              717141.532                    61.31
# 3    05/01/13 Sábado                682149.96                    58.11
# 4    06/01/13 Domingo              647854.785                    58.01
# ..                  ...                   ...                      ...
# 359  27/12/13 Viernes              663171.045                    15.39
# 360  28/12/13 Sábado                672714.85                    23.98
# 361  29/12/13 Domingo              634045.486                    42.83
# 362  30/12/13 Lunes                634951.745                    47.39
# 363  31/12/13 Martes               606765.004                    25.26
#
#     Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# ...

# %%
prices2013_brent = prices2013_brent.drop(columns= ["Day_y", "_merge", "% var."])
prices2013_brent.rename(columns={"Day_x":"Day"}, inplace= True)
prices2013_brent
# Out:
#                 Periodo Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# 0    02/01/13 Miércoles            681911.324                    50.75
# 1    03/01/13 Jueves               724426.458                    57.07
# 2    04/01/13 Viernes              717141.532                    61.31
# 3    05/01/13 Sábado                682149.96                    58.11
# 4    06/01/13 Domingo              647854.785                    58.01
# ..                  ...                   ...                      ...
# 359  27/12/13 Viernes              663171.045                    15.39
# 360  28/12/13 Sábado                672714.85                    23.98
# 361  29/12/13 Domingo              634045.486                    42.83
# 362  30/12/13 Lunes                634951.745                    47.39
# 363  31/12/13 Martes               606765.004                    25.26
#
#     Mercado \nintradiario \n€/MWh Restricciones\n€/MWh Procesos \nOS \n€/MWh  \
# ...

# %%
#The encoding = "latin1" is used so "special characters" like ñ is read well

listado_estaciones = pd.read_csv("/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Aemet2021-06-Por-Estaciones/ListadoEstaciones.csv", 
                                names =["Identificador_est", "Nombre_est", "Municipio", "Provincia", "Altura", "Longitud", "Latitud"],
                                         header= 0, dtype = str, engine= "python", sep=";", error_bad_lines= False,
                                encoding= "latin1")
listado_estaciones
# Out:
#     Identificador_est              Nombre_est           Municipio  \
# 0                1387                A Coruña           Coruña, A
# 1               1387E     A Coruña Aeropuerto           Culleredo
# 2               1390X    Carballo, Depuradora            Carballo
# 3                1393              Cabo Vilan           Camariñas
# 4                1399                Vimianzo            Vimianzo
# ..                ...                     ...                 ...
# 843             B640X                   Petra               Petra
# 844             9293X        Alfaro, La Plana              Alfaro
# 845             9445L       Formigal, Sarrios  Sallent de Gállego
# 846             9574B  Caspe, Plana del Pilón               Caspe
# 847             1387D           A Coruña Bens           Coruña, A
#
#          Provincia Altura Longitud  Latitud
# 0         A Coruña     58  432157N  082517W
# 1         A Coruña     98  431825N  082219W
# ...

# %% [markdown]
# I want to choose some weather stations that could represent the different temperatures across Spain (peninsula). So I have checked the most extreme latitude and longitude in the peninsula to pick some around there.
#
# ![title](Lat_lon_extreme.PNG)
#
# Also, looking at the map, let's choose some more stations in some provincies across the Spanish territory:
#
# ![title](Mapa-de-las-provincias-de-Espana.png)

# %%
listado_estaciones.iloc[4]["Longitud"]
# Out:
# '430327N'

# %%
in_coruña = listado_estaciones["Provincia"] == "A Coruña"
in_coruña
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 843    False
# 844    False
# 845    False
# 846    False
# 847     True
# Name: Provincia, Length: 848, dtype: bool

# %%
estaciones_coruña = listado_estaciones[in_coruña]
estaciones_coruña
# Out:
#     Identificador_est                         Nombre_est  \
# 0                1387                           A Coruña
# 1               1387E                A Coruña Aeropuerto
# 2               1390X               Carballo, Depuradora
# 3                1393                         Cabo Vilan
# 4                1399                           Vimianzo
# 5                1400                           Fisterra
# 6               1406X                          Mazaricos
# 7               1410X                            Sobrado
# 8                1428  Santiago de Compostela Aeropuerto
# 9               1435C                               Noia
# 10              1437O                       Monte Iroite
# 11              1442U                              Boiro
# 12              1473A                             Padrón
# 13              1475X             Santiago de Compostela
# 14              1476R               Rois, Casas do Porto
# ...

# %%
in_cadiz = listado_estaciones["Provincia"] == "Cádiz"
in_cadiz
estaciones_cadiz = listado_estaciones[in_cadiz]
estaciones_cadiz
# Out:
#     Identificador_est                       Nombre_est              Municipio  \
# 187             5906X                         Chipiona               Chipiona
# 188             5910X                 Rota, Base Naval                   Rota
# 189             5911A                        Grazalema              Grazalema
# 190             5919X                           Olvera                 Olvera
# 191             5941X                        El Bosque             Bosque, El
# 192             5950X               San José del Valle     San José del Valle
# 193              5960  Jerez de la Frontera Aeropuerto   Jerez de la Frontera
# 194             5972X                     San Fernando           San Fernando
# 195              5973                            Cádiz                  Cádiz
# 196             5983X                   Medina Sidonia         Medina-Sidonia
# 197             5995B             Vejer de la Frontera   Vejer de la Frontera
# ...

# %%
in_gerona = listado_estaciones["Provincia"] == "Girona"
in_gerona
estaciones_gerona = listado_estaciones[in_gerona]
estaciones_gerona
# Out:
#     Identificador_est             Nombre_est               Municipio  \
# 283             0281Y                 Blanes                  Blanes
# 284             0284X  Castell, Platja d`Aro   Castell, Platja d`Aro
# 285             0312X   Sant Pau de Segúries    Sant Pau de Segúries
# 286             0320I               Planoles                Planoles
# 287             0324A                 Ripoll                  Ripoll
# 288             0360X  Les Planes d'Hostoles  Planes d'Hostoles, Les
# 289             0363X            Sant Hilari      Sant Hilari Sacalm
# 290              0367      Girona Aeropuerto          Vilobí d'Onyar
# 291             0370E                 Girona                  Girona
# 292             0372C              Porqueres               Porqueres
# 293             0385X             L'Estartit    Torroella de Montgrí
# 294             0394X      La Vall de Bianya      Vall de Bianya, La
# 295             0411X    Castello d'Empuries     Castelló d'Empúries
# ...

# %%
for row in listado_estaciones.itertuples():
    
    print("El identificador de "+ row.Provincia +" "+ row.Nombre_est+ " es:"+ row.Identificador_est)
# Out:
# El identificador de A Coruña A Coruña es:1387
# El identificador de A Coruña A Coruña Aeropuerto es:1387E
# El identificador de A Coruña Carballo, Depuradora es:1390X
# El identificador de A Coruña Cabo Vilan es:1393
# El identificador de A Coruña Vimianzo es:1399
# El identificador de A Coruña Fisterra es:1400
# El identificador de A Coruña Mazaricos es:1406X
# El identificador de A Coruña Sobrado es:1410X
# El identificador de A Coruña Santiago de Compostela Aeropuerto es:1428
# El identificador de A Coruña Noia es:1435C
# El identificador de A Coruña Monte Iroite es:1437O
# El identificador de A Coruña Boiro es:1442U
# El identificador de A Coruña Padrón es:1473A
# El identificador de A Coruña Santiago de Compostela es:1475X
# El identificador de A Coruña Rois, Casas do Porto es:1476R
# El identificador de Albacete Ossa de Montiel es:4007Y
# El identificador de Albacete Villarrobledo es:4091Y
# El identificador de Albacete Munera es:4096Y
# ...

# %%
for row in listado_estaciones.itertuples():
    print(row)
# Out:
# Pandas(Index=0, Identificador_est='1387', Nombre_est='A Coruña', Municipio='Coruña, A', Provincia='A Coruña', Altura='58', Longitud='432157N', Latitud='082517W')
# Pandas(Index=1, Identificador_est='1387E', Nombre_est='A Coruña Aeropuerto', Municipio='Culleredo', Provincia='A Coruña', Altura='98', Longitud='431825N', Latitud='082219W')
# Pandas(Index=2, Identificador_est='1390X', Nombre_est='Carballo, Depuradora', Municipio='Carballo', Provincia='A Coruña', Altura='98', Longitud='431213N', Latitud='084239W')
# Pandas(Index=3, Identificador_est='1393', Nombre_est='Cabo Vilan', Municipio='Camariñas', Provincia='A Coruña', Altura='50', Longitud='430938N', Latitud='091239W')
# Pandas(Index=4, Identificador_est='1399', Nombre_est='Vimianzo', Municipio='Vimianzo', Provincia='A Coruña', Altura='287', Longitud='430327N', Latitud='090249W')
# ...

# %%
provincias = listado_estaciones["Provincia"].unique()
provincias = pd.DataFrame(list(provincias))
provincias
# Out:
#                          0
# 0                 A Coruña
# 1                 Albacete
# 2         Alacant/Alicante
# 3                  Almería
# 4              Araba/Álava
# 5                 Asturias
# 6                    Ávila
# 7                  Badajoz
# 8                Barcelona
# 9                  Bizkaia
# 10                  Burgos
# 11                 Cáceres
# 12                   Cádiz
# 13               Cantabria
# 14      Castelló/Castellón
# 15                   Ceuta
# 16             Ciudad Real
# 17                 Córdoba
# 18                  Cuenca
# 19                Gipuzkoa
# 20                  Girona
# 21                 Granada
# 22             Guadalajara
# 23                  Huelva
# 24                  Huesca
# 25           Illes Balears
# 26                    Jaén
# 27                La Rioja
# 28              Las Palmas
# 29                    León
# 30                  Lleida
# 31                    Lugo
# 32                  Madrid
# ...

# %%
listado_estaciones.sort_values("Provincia", inplace = True)
listado_estaciones
# Out:
#     Identificador_est              Nombre_est               Municipio  \
# 0                1387                A Coruña               Coruña, A
# 835             1354C                  Ferrol                  Ferrol
# 798              1351         Estaca de Bares                   Mañón
# 14              1476R    Rois, Casas do Porto                    Rois
# 13              1475X  Santiago de Compostela  Santiago de Compostela
# ..                ...                     ...                     ...
# 87              3319D          Puerto El Pico     Villarejo del Valle
# 803              3391    Sotillo de la Adrada    Sotillo de la Adrada
# 89              3422D               Candeleda               Candeleda
# 84              2512Y      Rivilla de Barajas      Rivilla de Barajas
# 88              3337U                Cebreros                Cebreros
#
#     Provincia Altura Longitud  Latitud
# 0    A Coruña     58  432157N  082517W
# 835  A Coruña      4  432835N  081533W
# ...

# %% [markdown]
# The next few cells do not work, as I was just trying to get the "Identificador de estación" without success

# %%
for provincia in listado_estaciones["Provincia"]:
    
    for i in range(len(provincias)):
    
        if provincia == provincias.iloc[i,0]:

            print(listado_estaciones["Identificador_est"])
# Out:
# 0       1387
# 835    1354C
# 798     1351
# 14     1476R
# 13     1475X
#        ...
# 87     3319D
# 803     3391
# 89     3422D
# 84     2512Y
# 88     3337U
# Name: Identificador_est, Length: 848, dtype: object
# 0       1387
# 835    1354C
# 798     1351
# 14     1476R
# 13     1475X
#        ...
# 87     3319D
# 803     3391
# 89     3422D
# 84     2512Y
# 88     3337U
# Name: Identificador_est, Length: 848, dtype: object
# 0       1387
# 835    1354C
# 798     1351
# 14     1476R
# 13     1475X
#        ...
# 87     3319D
# 803     3391
# 89     3422D
# 84     2512Y
# 88     3337U
# Name: Identificador_est, Length: 848, dtype: object
# 0       1387
# 835    1354C
# 798     1351
# 14     1476R
# 13     1475X
#        ...
# 87     3319D
# 803     3391
# 89     3422D
# 84     2512Y
# 88     3337U
# Name: Identificador_est, Length: 848, dtype: object
# 0       1387
# 835    1354C
# 798     1351
# 14     1476R
# 13     1475X
#        ...
# 87     3319D
# 803     3391
# ...

# %%
for index, fila in listado_estaciones.iterrows():
    
    print(fila["Provincia"], fila["Identificador_est"])
# Out:
# A Coruña 1387
# A Coruña 1354C
# A Coruña 1351
# A Coruña 1476R
# A Coruña 1475X
# A Coruña 1473A
# A Coruña 1442U
# A Coruña 1437O
# A Coruña 1435C
# A Coruña 1387D
# A Coruña 1410X
# A Coruña 1428
# A Coruña 1387E
# A Coruña 1393
# A Coruña 1390X
# A Coruña 1406X
# A Coruña 1400
# A Coruña 1399
# Alacant/Alicante 8050X
# Alacant/Alicante 8059C
# Alacant/Alicante 8057C
# Alacant/Alicante 8036Y
# Alacant/Alicante 8025
# Alacant/Alicante 8018X
# Alacant/Alicante 8013X
# Alacant/Alicante 8008Y
# Alacant/Alicante 7261X
# Alacant/Alicante 8019
# Alacant/Alicante 7244X
# Alacant/Alicante 7247X
# Albacete 4091Y
# Albacete 4096Y
# Albacete 8175
# Albacete 7066Y
# Albacete 7067Y
# Albacete 4007Y
# Albacete 7096B
# Albacete 7103Y
# Albacete 8198Y
# Albacete 8177A
# Albacete 8191Y
# Albacete 8178D
# Albacete 7072Y
# Almería 6332X
# Almería 6381
# Almería 6367B
# Almería 6364X
# Almería 6329X
# Almería 6325O
# Almería 6307X
# Almería 6302A
# Almería 6291B
# Almería 6277B
# Almería 5060X
# ...

# %%
# variable to hold the count
cnt = 0
  
# list to hold visited values
visited = []
  
# loop for counting the unique
# values in height
for i in range(0, len(listado_estaciones['Provincia'])):
    
    if listado_estaciones['Provincia'][i] not in visited: 
        
        visited.append(listado_estaciones['Provincia'][i])
          
        cnt += 1
  
print("No.of.unique values :",
      cnt)
  
print("unique values :",
      visited)
# Out:
# No.of.unique values : 52
# unique values : ['A Coruña', 'Albacete', 'Alacant/Alicante', 'Almería', 'Araba/Álava', 'Asturias', 'Ávila', 'Badajoz', 'Barcelona', 'Bizkaia', 'Burgos', 'Cáceres', 'Cádiz', 'Cantabria', 'Castelló/Castellón', 'Ceuta', 'Ciudad Real', 'Córdoba', 'Cuenca', 'Gipuzkoa', 'Girona', 'Granada', 'Guadalajara', 'Huelva', 'Huesca', 'Illes Balears', 'Jaén', 'La Rioja', 'Las Palmas', 'León', 'Lleida', 'Lugo', 'Madrid', 'Málaga', 'Melilla', 'Murcia', 'Navarra', 'Ourense', 'Palencia', 'Pontevedra', 'Salamanca', 'Segovia', 'Sevilla', 'Soria', 'Santa Cruz de Tenerife', 'Tarragona', 'Teruel', 'Toledo', 'València/Valencia', 'Valladolid', 'Zamora', 'Zaragoza']

# %%
#Here I'm randomly selecting one weather station for each province, excluding the Balearic and Canary Islands
#Also Ceuta and Melilla
s0 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("A Coruña")].sample(1, random_state=1).index
s1 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Albacete")].sample(1, random_state=1).index
s2 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Alacant/Alicante")].sample(1, random_state=1).index
s3 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Almería")].sample(1, random_state=1).index
s4 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Araba/Álava")].sample(1, random_state=1).index
s5 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Asturias")].sample(1, random_state=1).index
s6 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Ávila")].sample(1, random_state=1).index
s7 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Badajoz")].sample(1, random_state=1).index
s8 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Barcelona")].sample(1, random_state=1).index
s9 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Bizkaia")].sample(1, random_state=1).index
s10 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Burgos")].sample(1, random_state=1).index
s11 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Cáceres")].sample(1, random_state=1).index
s12 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Cádiz")].sample(1, random_state=1).index
s13 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Cantabria")].sample(1, random_state=1).index
s14 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Castelló/Castellón")].sample(1, random_state=1).index
s15 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Ciudad Real")].sample(1, random_state=1).index
s16 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Córdoba")].sample(1, random_state=1).index
s17 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Cuenca")].sample(1, random_state=1).index
s18 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Gipuzkoa")].sample(1, random_state=1).index
s19 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Girona")].sample(1, random_state=1).index
s20 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Granada")].sample(1, random_state=1).index
s21 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Guadalajara")].sample(1, random_state=1).index
s22 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Huelva")].sample(1, random_state=1).index
s23 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Huesca")].sample(1, random_state=1).index
s24 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Jaén")].sample(1, random_state=1).index
s25 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("La Rioja")].sample(1, random_state=1).index
s26 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("León")].sample(1, random_state=1).index
s27 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Lleida")].sample(1, random_state=1).index
s28 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Lugo")].sample(1, random_state=1).index
s29 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Madrid")].sample(1, random_state=1).index
s30 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Málaga")].sample(1, random_state=1).index
s31 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Murcia")].sample(1, random_state=1).index
s32 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Navarra")].sample(1, random_state=1).index
s33 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Ourense")].sample(1, random_state=1).index
s34 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Palencia")].sample(1, random_state=1).index
s35 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Pontevedra")].sample(1, random_state=1).index
s36 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Salamanca")].sample(1, random_state=1).index
s37 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Segovia")].sample(1, random_state=1).index
s38 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Sevilla")].sample(1, random_state=1).index
s39 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Soria")].sample(1, random_state=1).index
s40 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Tarragona")].sample(1, random_state=1).index
s41 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Teruel")].sample(1, random_state=1).index
s42 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Toledo")].sample(1, random_state=1).index
s43 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("València/Valencia")].sample(1, random_state=1).index
s44 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Valladolid")].sample(1, random_state=1).index
s45 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Zamora")].sample(1, random_state=1).index
s46 = listado_estaciones.Provincia[listado_estaciones.Provincia.eq("Zaragoza")].sample(1, random_state=1).index

random_weather_stations = listado_estaciones.loc[s0.union(s1).union(s2).union(s3).union(s4).union(s5).union(s6).union(s7).union(s8).
                            union(s9).union(s10).union(s11).union(s12).union(s13).union(s14).union(s15).union(s16).
                           union(s17).union(s18).union(s19).union(s20).union(s21).union(s22).union(s23).union(s24).
                           union(s25).union(s26).union(s27).union(s28).union(s29).union(s30).union(s31).union(s32).
                           union(s33).union(s34).union(s35).union(s36).union(s37).union(s38).union(s39).union(s40).
                           union(s41).union(s42).union(s43).union(s44).union(s45).union(s46)]
random_weather_stations
# Out:
#     Identificador_est                       Nombre_est  \
# 11              1442U                            Boiro
# 36              8057C                             Pego
# 48              6367B                    Huercal Overa
# 56              9178X                  Campezo/Kanpezu
# 60              1199X                           Piloña
# 82              2453E                     Gotarrendura
# 91               4260             Peraleda del Zaucejo
# 114             0066X           Vilafranca del Penedès
# 145             1083B                         Sopuerta
# 156              9051                  Medina de Pomar
# 171             3512X                     Montehermoso
# 191             5941X                        El Bosque
# 211             1154H         Torrelavega, Sierrapando
# 222             8489X  Villafranca del Cid/Villafranca
# 231             4103X                        Tomelloso
# 255             5625X                        La Rambla
# ...

# %%
len(random_weather_stations)
# Out:
# 47

# %%
identificadores = random_weather_stations["Identificador_est"]
identificadores =list(identificadores)
identificadores
# Out:
# ['1442U',
#  '8057C',
#  '6367B',
#  '9178X',
#  '1199X',
#  '2453E',
#  '4260',
#  '0066X',
#  '1083B',
#  '9051',
#  '3512X',
#  '5941X',
#  '1154H',
#  '8489X',
#  '4103X',
#  '5625X',
#  '3094B',
#  '1050J',
#  '0394X',
#  '6281X',
#  '3103',
#  '4622X',
#  '9211F',
#  '5038X',
#  '9115X',
#  '1541B',
#  '9647X',
#  '1342X',
#  '6106X',
#  '7195X',
#  '9218A',
#  '2978X',
#  '2374X',
#  '1730E',
#  '2918Y',
#  '2140A',
#  '5612B',
#  '2048A',
#  '0009X',
#  '9374X',
#  '3254Y',
#  '8416Y',
#  '2166Y',
#  '2536D',
#  '9321X',
#  '8175',
#  '3344E']

# %%
path_datos_estaciones = "/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Aemet2021-06-Por-Estaciones/DatosEstaciones - 2021-06/Randomly_selected_1/"

# %%
#This reads all the relevant weather stations csv:

import pandas as pd
import glob

path = path_datos_estaciones

all_relevant_files = glob.glob(path + "*.csv")

li = []

for filename in all_relevant_files:
    df = pd.read_csv(filename, index_col=None, header=0, sep =";", dtype= str)
    li.append(df)

weather_data = pd.concat(li, axis=0, ignore_index=True)
weather_data
# Out:
#            Id       Fecha  Tmax  HTmax  Tmin  HTmin  Tmed Racha HRacha Vmax  \
# 0       0009X  2013-05-07  25.4  17:40  14.6  00:30    20    44  16:30   24
# 1       0009X  2013-05-08  24.3  18:20  14.4  05:00  19.3    30  16:20   15
# 2       0009X  2013-05-09  21.6  16:50  12.7  05:00  17.2    25  23:20   16
# 3       0009X  2013-05-10  21.7  17:10  11.4  05:50  16.6    50  13:20   29
# 4       0009X  2013-05-11  22.3  16:40  10.8  01:00  16.5    46  13:30   26
# ...       ...         ...   ...    ...   ...    ...   ...   ...    ...  ...
# 133091  9647X  2021-06-26  30.4  16:00  14.3  06:20  22.3   NaN    NaN  NaN
# 133092  9647X  2021-06-27  32.2  15:00  14.3  06:10  23.3   NaN    NaN  NaN
# 133093  9647X  2021-06-28  29.1  17:30  15.4  06:00  22.3   NaN    NaN  NaN
# 133094  9647X  2021-06-29  28.2  18:20  11.6  03:00  19.9   NaN    NaN  NaN
# 133095  9647X  2021-06-30  28.2  18:40  16.4  02:50  22.3   NaN    NaN  NaN
#
#         HVmax TPrec Prec1 Prec2 Prec3 Prec4
# ...

# %%
weather_data.rename(columns = {"Id": "Identificador_est"}, inplace= True)

# %%
weather_data = pd.merge(weather_data, 
                     random_weather_stations, 
                     on ='Identificador_est',
                       how= "left")
weather_data
# Out:
#        Identificador_est       Fecha  Tmax  HTmax  Tmin  HTmin  Tmed Racha  \
# 0                  0009X  2013-05-07  25.4  17:40  14.6  00:30    20    44
# 1                  0009X  2013-05-08  24.3  18:20  14.4  05:00  19.3    30
# 2                  0009X  2013-05-09  21.6  16:50  12.7  05:00  17.2    25
# 3                  0009X  2013-05-10  21.7  17:10  11.4  05:50  16.6    50
# 4                  0009X  2013-05-11  22.3  16:40  10.8  01:00  16.5    46
# ...                  ...         ...   ...    ...   ...    ...   ...   ...
# 133091             9647X  2021-06-26  30.4  16:00  14.3  06:20  22.3   NaN
# 133092             9647X  2021-06-27  32.2  15:00  14.3  06:10  23.3   NaN
# 133093             9647X  2021-06-28  29.1  17:30  15.4  06:00  22.3   NaN
# 133094             9647X  2021-06-29  28.2  18:20  11.6  03:00  19.9   NaN
# 133095             9647X  2021-06-30  28.2  18:40  16.4  02:50  22.3   NaN
#
# ...

# %%
poblacion_path = "/home/dsc/CarpetaCompartida/TFM/Data/Precios de la electricidad/Cifras oficiales de población resultantes de la revisión del Padrón municipal 2020.csv"

# %%
poblacion = pd.read_csv(poblacion_path, dtype = str, engine= "python", sep=";", encoding= "latin1")
poblacion
# Out:
#                    Provincias   Sexo Periodo      Total
# 0                 02 Albacete  Total    2020    388.270
# 1         03 Alicante/Alacant  Total    2020  1.879.888
# 2                  04 Almería  Total    2020    727.945
# 3              01 Araba/Álava  Total    2020    333.940
# 4                 33 Asturias  Total    2020  1.018.784
# 5                    05 Ávila  Total    2020    157.664
# 6                  06 Badajoz  Total    2020    672.137
# 7           07 Balears, Illes  Total    2020  1.171.543
# 8                08 Barcelona  Total    2020  5.743.402
# 9                  48 Bizkaia  Total    2020  1.159.443
# 10                  09 Burgos  Total    2020    357.650
# 11                 10 Cáceres  Total    2020    391.850
# 12                   11 Cádiz  Total    2020  1.244.049
# 13               39 Cantabria  Total    2020    582.905
# 14      12 Castellón/Castelló  Total    2020    585.590
# 15             13 Ciudad Real  Total    2020    495.045
# ...

# %%
poblacion[["Code", "Provincia"]] = poblacion.Provincias.str.split(" ",1, expand=True)
poblacion
# Out:
#                    Provincias   Sexo Periodo      Total Code  \
# 0                 02 Albacete  Total    2020    388.270   02
# 1         03 Alicante/Alacant  Total    2020  1.879.888   03
# 2                  04 Almería  Total    2020    727.945   04
# 3              01 Araba/Álava  Total    2020    333.940   01
# 4                 33 Asturias  Total    2020  1.018.784   33
# 5                    05 Ávila  Total    2020    157.664   05
# 6                  06 Badajoz  Total    2020    672.137   06
# 7           07 Balears, Illes  Total    2020  1.171.543   07
# 8                08 Barcelona  Total    2020  5.743.402   08
# 9                  48 Bizkaia  Total    2020  1.159.443   48
# 10                  09 Burgos  Total    2020    357.650   09
# 11                 10 Cáceres  Total    2020    391.850   10
# 12                   11 Cádiz  Total    2020  1.244.049   11
# 13               39 Cantabria  Total    2020    582.905   39
# ...

# %%
poblacion = poblacion.drop(["Provincias", "Sexo", "Periodo", "Code"], axis = 1)
poblacion
# Out:
#         Total               Provincia
# 0     388.270                Albacete
# 1   1.879.888        Alicante/Alacant
# 2     727.945                 Almería
# 3     333.940             Araba/Álava
# 4   1.018.784                Asturias
# 5     157.664                   Ávila
# 6     672.137                 Badajoz
# 7   1.171.543          Balears, Illes
# 8   5.743.402               Barcelona
# 9   1.159.443                 Bizkaia
# 10    357.650                  Burgos
# 11    391.850                 Cáceres
# 12  1.244.049                   Cádiz
# 13    582.905               Cantabria
# 14    585.590      Castellón/Castelló
# 15    495.045             Ciudad Real
# 16    781.451                 Córdoba
# 17  1.121.815               Coruña, A
# 18    196.139                  Cuenca
# 19    727.121                Gipuzkoa
# 20    781.788                  Girona
# 21    919.168                 Granada
# 22    261.995             Guadalajara
# 23    524.278                  Huelva
# ...

# %%
poblacion["Provincia"].unique()
# Out:
# array(['Albacete', 'Alicante/Alacant', 'Almería', 'Araba/Álava',
#        'Asturias', 'Ávila', 'Badajoz', 'Balears, Illes', 'Barcelona',
#        'Bizkaia', 'Burgos', 'Cáceres', 'Cádiz', 'Cantabria',
#        'Castellón/Castelló', 'Ciudad Real', 'Córdoba', 'Coruña, A',
#        'Cuenca', 'Gipuzkoa', 'Girona', 'Granada', 'Guadalajara', 'Huelva',
#        'Huesca', 'Jaén', 'León', 'Lleida', 'Lugo', 'Madrid', 'Málaga',
#        'Murcia', 'Navarra', 'Ourense', 'Palencia', 'Palmas, Las',
#        'Pontevedra', 'Rioja, La', 'Salamanca', 'Santa Cruz de Tenerife',
#        'Segovia', 'Sevilla', 'Soria', 'Tarragona', 'Teruel', 'Toledo',
#        'Valencia/València', 'Valladolid', 'Zamora', 'Zaragoza', 'Ceuta',
#        'Melilla'], dtype=object)

# %%
weather_data["Provincia"].unique()
# Out:
# array(['Tarragona', 'Barcelona', 'Girona', 'Gipuzkoa', 'Bizkaia',
#        'Cantabria', 'Asturias', 'Lugo', 'A Coruña', 'León', 'Pontevedra',
#        'Soria', 'Segovia', 'Valladolid', 'Palencia', 'Ávila', 'Zamora',
#        'Salamanca', 'Ourense', 'Cuenca', 'Guadalajara', 'Toledo',
#        'Madrid', 'Cáceres', 'Ciudad Real', 'Badajoz', 'Huelva', 'Jaén',
#        'Sevilla', 'Córdoba', 'Cádiz', 'Málaga', 'Granada', 'Almería',
#        'Murcia', 'Alacant/Alicante', 'Albacete', 'València/Valencia',
#        'Castelló/Castellón', 'Burgos', 'La Rioja', 'Araba/Álava',
#        'Huesca', 'Navarra', 'Zaragoza', 'Teruel', 'Lleida'], dtype=object)

# %%
provincias_stations = random_weather_stations["Provincia"]
provincias_stations = pd.DataFrame(provincias_stations).reset_index().drop(columns="index")
provincias_stations
# Out:
#              Provincia
# 0             A Coruña
# 1     Alacant/Alicante
# 2              Almería
# 3          Araba/Álava
# 4             Asturias
# 5                Ávila
# 6              Badajoz
# 7            Barcelona
# 8              Bizkaia
# 9               Burgos
# 10             Cáceres
# 11               Cádiz
# 12           Cantabria
# 13  Castelló/Castellón
# 14         Ciudad Real
# 15             Córdoba
# 16              Cuenca
# 17            Gipuzkoa
# 18              Girona
# 19             Granada
# 20         Guadalajara
# 21              Huelva
# 22              Huesca
# 23                Jaén
# 24            La Rioja
# 25                León
# 26              Lleida
# 27                Lugo
# 28              Málaga
# 29              Murcia
# 30             Navarra
# 31             Ourense
# 32            Palencia
# 33          Pontevedra
# 34           Salamanca
# 35             Segovia
# 36             Sevilla
# 37               Soria
# 38           Tarragona
# ...

# %%
provincias_poblacion = poblacion["Provincia"]
provincias_poblacion = pd.DataFrame(provincias_poblacion).reset_index().drop(columns="index")
provincias_poblacion
# Out:
#                  Provincia
# 0                 Albacete
# 1         Alicante/Alacant
# 2                  Almería
# 3              Araba/Álava
# 4                 Asturias
# 5                    Ávila
# 6                  Badajoz
# 7           Balears, Illes
# 8                Barcelona
# 9                  Bizkaia
# 10                  Burgos
# 11                 Cáceres
# 12                   Cádiz
# 13               Cantabria
# 14      Castellón/Castelló
# 15             Ciudad Real
# 16                 Córdoba
# 17               Coruña, A
# 18                  Cuenca
# 19                Gipuzkoa
# 20                  Girona
# 21                 Granada
# 22             Guadalajara
# 23                  Huelva
# 24                  Huesca
# 25                    Jaén
# 26                    León
# 27                  Lleida
# 28                    Lugo
# 29                  Madrid
# 30                  Málaga
# 31                  Murcia
# 32                 Navarra
# ...

# %%
different_names = provincias_stations.merge(right = provincias_poblacion, how= "left", indicator=True)

different_names = different_names[different_names['_merge']=='left_only']
different_names
# Out:
#              Provincia     _merge
# 0             A Coruña  left_only
# 1     Alacant/Alicante  left_only
# 13  Castelló/Castellón  left_only
# 24            La Rioja  left_only
# 41   València/Valencia  left_only

# %%
#I'm changing the name in the population dataframe so it matches the weather stations one, for those that are not the same
poblacion.loc[17, "Provincia"] = "A Coruña"
poblacion.loc[1, "Provincia"] = "Alacant/Alicante"
poblacion.loc[14, "Provincia"] = "Castelló/Castellón"
poblacion.loc[37, "Provincia"] = "La Rioja"
poblacion.loc[46, "Provincia"] = "València/Valencia"

# %%
weather_data_population = weather_data.merge(right= poblacion, on= "Provincia", how= "left")
weather_data_population
# Out:
#        Identificador_est       Fecha  Tmax  HTmax  Tmin  HTmin  Tmed Racha  \
# 0                  0009X  2013-05-07  25.4  17:40  14.6  00:30    20    44
# 1                  0009X  2013-05-08  24.3  18:20  14.4  05:00  19.3    30
# 2                  0009X  2013-05-09  21.6  16:50  12.7  05:00  17.2    25
# 3                  0009X  2013-05-10  21.7  17:10  11.4  05:50  16.6    50
# 4                  0009X  2013-05-11  22.3  16:40  10.8  01:00  16.5    46
# ...                  ...         ...   ...    ...   ...    ...   ...   ...
# 133091             9647X  2021-06-26  30.4  16:00  14.3  06:20  22.3   NaN
# 133092             9647X  2021-06-27  32.2  15:00  14.3  06:10  23.3   NaN
# 133093             9647X  2021-06-28  29.1  17:30  15.4  06:00  22.3   NaN
# 133094             9647X  2021-06-29  28.2  18:20  11.6  03:00  19.9   NaN
# 133095             9647X  2021-06-30  28.2  18:40  16.4  02:50  22.3   NaN
#
# ...

# %%
weather_data_population.rename(columns= {"Total": "Población"}, inplace=True)
weather_data_population
# Out:
#        Identificador_est       Fecha  Tmax  HTmax  Tmin  HTmin  Tmed Racha  \
# 0                  0009X  2013-05-07  25.4  17:40  14.6  00:30    20    44
# 1                  0009X  2013-05-08  24.3  18:20  14.4  05:00  19.3    30
# 2                  0009X  2013-05-09  21.6  16:50  12.7  05:00  17.2    25
# 3                  0009X  2013-05-10  21.7  17:10  11.4  05:50  16.6    50
# 4                  0009X  2013-05-11  22.3  16:40  10.8  01:00  16.5    46
# ...                  ...         ...   ...    ...   ...    ...   ...   ...
# 133091             9647X  2021-06-26  30.4  16:00  14.3  06:20  22.3   NaN
# 133092             9647X  2021-06-27  32.2  15:00  14.3  06:10  23.3   NaN
# 133093             9647X  2021-06-28  29.1  17:30  15.4  06:00  22.3   NaN
# 133094             9647X  2021-06-29  28.2  18:20  11.6  03:00  19.9   NaN
# 133095             9647X  2021-06-30  28.2  18:40  16.4  02:50  22.3   NaN
#
# ...

# %%
weather_data_population = weather_data_population.drop({"HTmax", "HTmin", "Racha", "HRacha", 
                                                        "HVmax", "Prec1", "Prec2", "Prec3", "Prec4", "Municipio" },
                                                       axis = 1)
weather_data_population
# Out:
#        Identificador_est       Fecha  Tmax  Tmin  Tmed Vmax TPrec Nombre_est  \
# 0                  0009X  2013-05-07  25.4  14.6    20   24     0    Alforja
# 1                  0009X  2013-05-08  24.3  14.4  19.3   15     0    Alforja
# 2                  0009X  2013-05-09  21.6  12.7  17.2   16   1.8    Alforja
# 3                  0009X  2013-05-10  21.7  11.4  16.6   29     0    Alforja
# 4                  0009X  2013-05-11  22.3  10.8  16.5   26     0    Alforja
# ...                  ...         ...   ...   ...   ...  ...   ...        ...
# 133091             9647X  2021-06-26  30.4  14.3  22.3  NaN     0       Torà
# 133092             9647X  2021-06-27  32.2  14.3  23.3  NaN     0       Torà
# 133093             9647X  2021-06-28  29.1  15.4  22.3  NaN     0       Torà
# 133094             9647X  2021-06-29  28.2  11.6  19.9  NaN     0       Torà
# 133095             9647X  2021-06-30  28.2  16.4  22.3  NaN     0       Torà
#
# ...

# %%
weather_data_population.isnull().any()
# Out:
# Identificador_est    False
# Fecha                False
# Tmax                  True
# Tmin                  True
# Tmed                  True
# Vmax                  True
# TPrec                 True
# Nombre_est           False
# Provincia            False
# Altura               False
# Longitud             False
# Latitud              False
# Población            False
# dtype: bool

# %%
weather_data_population.isnull().sum()
# Out:
# Identificador_est        0
# Fecha                    0
# Tmax                  8793
# Tmin                  8793
# Tmed                  8793
# Vmax                 32893
# TPrec                10609
# Nombre_est               0
# Provincia                0
# Altura                   0
# Longitud                 0
# Latitud                  0
# Población                0
# dtype: int64

# %%
nan_rows = weather_data_population[weather_data_population.isnull().any(1)]
nan_rows
# Out:
#        Identificador_est       Fecha  Tmax  Tmin  Tmed Vmax TPrec Nombre_est  \
# 12                 0009X  2013-05-19   NaN   NaN   NaN  NaN   NaN    Alforja
# 99                 0009X  2013-08-14   NaN   NaN   NaN  NaN   NaN    Alforja
# 100                0009X  2013-08-15   NaN   NaN   NaN  NaN   NaN    Alforja
# 101                0009X  2013-08-16   NaN   NaN   NaN  NaN   NaN    Alforja
# 118                0009X  2013-09-02   NaN   NaN   NaN  NaN   NaN    Alforja
# ...                  ...         ...   ...   ...   ...  ...   ...        ...
# 133091             9647X  2021-06-26  30.4  14.3  22.3  NaN     0       Torà
# 133092             9647X  2021-06-27  32.2  14.3  23.3  NaN     0       Torà
# 133093             9647X  2021-06-28  29.1  15.4  22.3  NaN     0       Torà
# 133094             9647X  2021-06-29  28.2  11.6  19.9  NaN     0       Torà
# 133095             9647X  2021-06-30  28.2  16.4  22.3  NaN     0       Torà
#
# ...

# %%
#I'm going to fill the NaN values with the last valid observation. 
#I'm assuming the first row of each different weather stations never has any NaN values.
#That must not always be the case, but let's assume that for now.

weather_data_population_noNan = weather_data_population.fillna(method= "ffill")
weather_data_population_noNan
# Out:
#        Identificador_est       Fecha  Tmax  Tmin  Tmed Vmax TPrec Nombre_est  \
# 0                  0009X  2013-05-07  25.4  14.6    20   24     0    Alforja
# 1                  0009X  2013-05-08  24.3  14.4  19.3   15     0    Alforja
# 2                  0009X  2013-05-09  21.6  12.7  17.2   16   1.8    Alforja
# 3                  0009X  2013-05-10  21.7  11.4  16.6   29     0    Alforja
# 4                  0009X  2013-05-11  22.3  10.8  16.5   26     0    Alforja
# ...                  ...         ...   ...   ...   ...  ...   ...        ...
# 133091             9647X  2021-06-26  30.4  14.3  22.3   24     0       Torà
# 133092             9647X  2021-06-27  32.2  14.3  23.3   24     0       Torà
# 133093             9647X  2021-06-28  29.1  15.4  22.3   24     0       Torà
# 133094             9647X  2021-06-29  28.2  11.6  19.9   24     0       Torà
# 133095             9647X  2021-06-30  28.2  16.4  22.3   24     0       Torà
#
# ...

# %%
weather_data_population_noNan.isnull().sum()
# Out:
# Identificador_est    0
# Fecha                0
# Tmax                 0
# Tmin                 0
# Tmed                 0
# Vmax                 0
# TPrec                0
# Nombre_est           0
# Provincia            0
# Altura               0
# Longitud             0
# Latitud              0
# Población            0
# dtype: int64

# %%
weather_data_population_noNan["Fecha"] = pd.to_datetime(weather_data_population_noNan["Fecha"])

# %%
weather_data_population_noNan.dtypes
# Out:
# Identificador_est            object
# Fecha                datetime64[ns]
# Tmax                         object
# Tmin                         object
# Tmed                         object
# Vmax                         object
# TPrec                        object
# Nombre_est                   object
# Provincia                    object
# Altura                       object
# Longitud                     object
# Latitud                      object
# Población                    object
# dtype: object

# %%
weather_data_population_noNan = weather_data_population_noNan.sort_values(["Fecha"])
weather_data_population_noNan
# Out:
#        Identificador_est      Fecha  Tmax  Tmin  Tmed Vmax TPrec  \
# 0                  0009X 2013-05-07  25.4  14.6    20   24     0
# 48892              2918Y 2013-05-07  18.1  10.7  14.4   24   0.8
# 51860              2978X 2013-05-07  18.7  12.7  15.7   19   0.4
# 104314             8416Y 2013-05-07  32.1  16.1  24.1   17     0
# 54828              3094B 2013-05-07  23.5  12.5    18   19     0
# ...                  ...        ...   ...   ...   ...  ...   ...
# 51859              2918Y 2021-06-30  27.4   8.3  17.8   19     0
# 104313              8175 2021-06-30  32.2  16.8  24.5   24     0
# 54827              2978X 2021-06-30  29.0   7.9  18.5   19     0
# 31228              1730E 2021-06-30  24.2  12.1  18.2   24     0
# 133095             9647X 2021-06-30  28.2  16.4  22.3   24     0
#
#                  Nombre_est          Provincia Altura Longitud  Latitud  \
# 0                   Alforja          Tarragona    406  411250N  005748E
# ...

# %%
weather_data_population_noNan['Población'] = weather_data_population_noNan['Población'].str.replace('.', '')
weather_data_population_noNan
# Out:
#        Identificador_est      Fecha  Tmax  Tmin  Tmed Vmax TPrec  \
# 0                  0009X 2013-05-07  25.4  14.6    20   24     0
# 48892              2918Y 2013-05-07  18.1  10.7  14.4   24   0.8
# 51860              2978X 2013-05-07  18.7  12.7  15.7   19   0.4
# 104314             8416Y 2013-05-07  32.1  16.1  24.1   17     0
# 54828              3094B 2013-05-07  23.5  12.5    18   19     0
# ...                  ...        ...   ...   ...   ...  ...   ...
# 51859              2918Y 2021-06-30  27.4   8.3  17.8   19     0
# 104313              8175 2021-06-30  32.2  16.8  24.5   24     0
# 54827              2978X 2021-06-30  29.0   7.9  18.5   19     0
# 31228              1730E 2021-06-30  24.2  12.1  18.2   24     0
# 133095             9647X 2021-06-30  28.2  16.4  22.3   24     0
#
#                  Nombre_est          Provincia Altura Longitud  Latitud  \
# 0                   Alforja          Tarragona    406  411250N  005748E
# ...

# %%
weather_data_population_noNan["Tmax"] = pd.to_numeric(weather_data_population_noNan["Tmax"], downcast="float")
weather_data_population_noNan["Tmin"] = pd.to_numeric(weather_data_population_noNan["Tmin"], downcast="float")
weather_data_population_noNan["Tmed"] = pd.to_numeric(weather_data_population_noNan["Tmed"], downcast="float")
weather_data_population_noNan["Vmax"] = pd.to_numeric(weather_data_population_noNan["Vmax"], downcast="float")
weather_data_population_noNan["TPrec"] = pd.to_numeric(weather_data_population_noNan["TPrec"], downcast="float")
weather_data_population_noNan["Altura"] = pd.to_numeric(weather_data_population_noNan["Altura"], downcast="integer")
weather_data_population_noNan["Población"] = pd.to_numeric(weather_data_population_noNan["Población"], downcast="float")
weather_data_population_noNan.dtypes
# Out:
# Identificador_est            object
# Fecha                datetime64[ns]
# Tmax                        float32
# Tmin                        float32
# Tmed                        float32
# Vmax                        float32
# TPrec                       float32
# Nombre_est                   object
# Provincia                    object
# Altura                        int16
# Longitud                     object
# Latitud                      object
# Población                   float32
# dtype: object

# %%
#from numpy import average
#weather_data_population_noNan_numpy = weather_data_population_noNan.to_numpy()
#weather_data_population_noNan_numpy.average(
#    weather_data_population_noNan_numpy["Tmax"], weights= weather_data_population_noNan_numpy["Población"])

# %% [raw]
# #This is not working
# def weighted_mean(df, values, weights, groupby):
#     df = df.copy()
#     grouped = df.groupby(groupby)
#     df['weighted_average'] = df[values] / grouped[weights].transform('sum') * df[weights]
#     return grouped['weighted_average'].sum(min_count=1) #min_count is required for Grouper objects

# %% [raw]
# def grouped_weighted_avg(values, weights, by):
#         return (values * weights).groupby(by).sum() / weights.groupby(by).sum()

# %%
def grouped_weighted_avg_Tmax(values, weights, by):
    return pd.DataFrame((values * weights).groupby(by).sum() / weights.groupby(by).sum(), columns= ["Tmax"])

def grouped_weighted_avg_Tmin(values, weights, by):
    return pd.DataFrame((values * weights).groupby(by).sum() / weights.groupby(by).sum(), columns= ["Tmin"])

# %%
weighted_av_Tmax = grouped_weighted_avg_Tmax(values= weather_data_population_noNan["Tmax"],
                         weights= weather_data_population_noNan["Población"],
                         by= weather_data_population_noNan["Fecha"])

weighted_av_Tmax
# Out:
#                  Tmax
# Fecha
# 2013-05-07  26.024410
# 2013-05-08  25.336803
# 2013-05-09  23.381573
# 2013-05-10  22.928568
# 2013-05-11  22.691177
# ...               ...
# 2021-06-26  29.056046
# 2021-06-27  27.982450
# 2021-06-28  27.139305
# 2021-06-29  27.944527
# 2021-06-30  28.744200
#
# [2968 rows x 1 columns]

# %%
weather_data_population_noNan["Tmax"].mean()
# Out:
# 20.569137573242188

# %%
weighted_av_Tmin = grouped_weighted_avg_Tmin(values= weather_data_population_noNan["Tmin"],
                         weights= weather_data_population_noNan["Población"],
                         by= weather_data_population_noNan["Fecha"])
weighted_av_Tmin
# Out:
#                  Tmin
# Fecha
# 2013-05-07  13.555936
# 2013-05-08  14.118225
# 2013-05-09  13.126208
# 2013-05-10  12.023178
# 2013-05-11  10.655726
# ...               ...
# 2021-06-26  15.605719
# 2021-06-27  14.947507
# 2021-06-28  13.948045
# 2021-06-29  13.623206
# 2021-06-30  15.174376
#
# [2968 rows x 1 columns]

# %%
def grouped_weighted_avg_Tmed(values, weights, by):
    return pd.DataFrame((values * weights).groupby(by).sum() / weights.groupby(by).sum(), columns= ["Tmed"])

def grouped_weighted_avg_Vmax(values, weights, by):
    return pd.DataFrame((values * weights).groupby(by).sum() / weights.groupby(by).sum(), columns= ["Vmax"])

def grouped_weighted_avg_Tprec(values, weights, by):
    return pd.DataFrame((values * weights).groupby(by).sum() / weights.groupby(by).sum(), columns= ["TPrec"])

def grouped_weighted_avg_Altura(values, weights, by):
    return pd.DataFrame((values * weights).groupby(by).sum() / weights.groupby(by).sum(), columns= ["Altura"])

# %%
weighted_av_Tmed = grouped_weighted_avg_Tmed(values= weather_data_population_noNan["Tmed"],
                         weights= weather_data_population_noNan["Población"],
                         by= weather_data_population_noNan["Fecha"])

weighted_av_Vmax = grouped_weighted_avg_Vmax(values= weather_data_population_noNan["Vmax"],
                         weights= weather_data_population_noNan["Población"],
                         by= weather_data_population_noNan["Fecha"])

weighted_av_Tprec = grouped_weighted_avg_Tprec(values= weather_data_population_noNan["TPrec"],
                         weights= weather_data_population_noNan["Población"],
                         by= weather_data_population_noNan["Fecha"])

weighted_av_Altura = grouped_weighted_avg_Altura(values= weather_data_population_noNan["Altura"],
                         weights= weather_data_population_noNan["Población"],
                         by= weather_data_population_noNan["Fecha"])

# %%
weather_variables_list = [weighted_av_Tmax, weighted_av_Tmin, weighted_av_Tmed,
                          weighted_av_Vmax, weighted_av_Tprec, weighted_av_Altura]

weather_variables = weather_variables_list[0].join(weather_variables_list[1:])
weather_variables
# Out:
#                  Tmax       Tmin       Tmed       Vmax     TPrec      Altura
# Fecha
# 2013-05-07  26.024410  13.555936  19.797901  17.838921  2.095502  388.574585
# 2013-05-08  25.336803  14.118225  19.728336  15.444501  0.565097  388.574585
# 2013-05-09  23.381573  13.126208  18.251265  15.949620  1.760222  377.103973
# 2013-05-10  22.928568  12.023178  17.480787  16.672112  0.249773  377.103973
# 2013-05-11  22.691177  10.655726  16.671419  15.552441  0.003383  377.103973
# ...               ...        ...        ...        ...       ...         ...
# 2021-06-26  29.056046  15.605719  22.344318  21.181517  0.156258  440.388000
# 2021-06-27  27.982450  14.947507  21.477276  21.588980  0.356326  440.388000
# 2021-06-28  27.139305  13.948045  20.551270  18.703827  0.131306  440.388000
# 2021-06-29  27.944527  13.623206  20.784426  16.571365  0.001755  440.388000
# 2021-06-30  28.744200  15.174376  21.980579  18.588869  0.141748  440.388000
#
# [2968 rows x 6 columns]

# %%
weather_variables.rename_axis("Date", axis= "index", inplace=True)
weather_variables
# Out:
#                  Tmax       Tmin       Tmed       Vmax     TPrec      Altura
# Date
# 2013-05-07  26.024410  13.555936  19.797901  17.838921  2.095502  388.574585
# 2013-05-08  25.336803  14.118225  19.728336  15.444501  0.565097  388.574585
# 2013-05-09  23.381573  13.126208  18.251265  15.949620  1.760222  377.103973
# 2013-05-10  22.928568  12.023178  17.480787  16.672112  0.249773  377.103973
# 2013-05-11  22.691177  10.655726  16.671419  15.552441  0.003383  377.103973
# ...               ...        ...        ...        ...       ...         ...
# 2021-06-26  29.056046  15.605719  22.344318  21.181517  0.156258  440.388000
# 2021-06-27  27.982450  14.947507  21.477276  21.588980  0.356326  440.388000
# 2021-06-28  27.139305  13.948045  20.551270  18.703827  0.131306  440.388000
# 2021-06-29  27.944527  13.623206  20.784426  16.571365  0.001755  440.388000
# 2021-06-30  28.744200  15.174376  21.980579  18.588869  0.141748  440.388000
#
# [2968 rows x 6 columns]

# %%
prices2013_brent.set_index("Date", inplace=True)

# %%
prices2013_brent.drop("Periodo", inplace= True, axis= 1)

# %%
prices2013_brent
# Out:
#            Energía\n final \nMWh Mercado \ndiario \n€/MWh  \
# Date
# 2013-02-01            681911.324                    50.75
# 2013-03-01            724426.458                    57.07
# 2013-04-01            717141.532                    61.31
# 2013-05-01             682149.96                    58.11
# 2013-06-01            647854.785                    58.01
# ...                          ...                      ...
# 2013-12-27            663171.045                    15.39
# 2013-12-28             672714.85                    23.98
# 2013-12-29            634045.486                    42.83
# 2013-12-30            634951.745                    47.39
# 2013-12-31            606765.004                    25.26
#
#            Mercado \nintradiario \n€/MWh Restricciones\n€/MWh  \
# Date
# 2013-02-01                          0.12                 3.15
# 2013-03-01                         -0.13                 1.92
# 2013-04-01                         -0.08                 1.71
# ...

# %%
prices2013_brent.columns
# Out:
# Index(['Energía\n final \nMWh', 'Mercado \ndiario \n€/MWh',
#        'Mercado \nintradiario \n€/MWh', 'Restricciones\n€/MWh',
#        'Procesos \nOS \n€/MWh', 'Garantía potencia \nPagos capacidad\n€/MWh',
#        'Total\n€/MWh', 'Day', 'Último', 'Apertura', 'Máximo', 'Mínimo',
#        'Vol.'],
#       dtype='object')

# %%
prices2013_brent.rename(columns= {"Energía\n final \nMWh": "Energía final MWh", 
                                  "Mercado \ndiario \n€/MWh": "Mercado diario €/MWh",
                                 "Mercado \nintradiario \n€/MWh": "Mercado intradiario €/MWh",
                                 "Restricciones\n€/MWh": "Restricciones €/MWh",
                                 "Procesos \nOS \n€/MWh": "Procesos OS €/MWh",
                                 "Garantía potencia \nPagos capacidad\n€/MWh": "Garantía potencia Pagos capacidad €/MWh",
                                 "Total\n€/MWh": "Total €/MWh"}, inplace=True)

# %%
prices2013_brent
# Out:
#            Energía final MWh Mercado diario €/MWh Mercado intradiario €/MWh  \
# Date
# 2013-02-01        681911.324                50.75                      0.12
# 2013-03-01        724426.458                57.07                     -0.13
# 2013-04-01        717141.532                61.31                     -0.08
# 2013-05-01         682149.96                58.11                      0.14
# 2013-06-01        647854.785                58.01                         0
# ...                      ...                  ...                       ...
# 2013-12-27        663171.045                15.39                         0
# 2013-12-28         672714.85                23.98                      0.01
# 2013-12-29        634045.486                42.83                     -0.13
# 2013-12-30        634951.745                47.39                     -0.57
# 2013-12-31        606765.004                25.26                     -0.15
#
# ...

# %%
prices2013_brent_weather = prices2013_brent.merge(weather_variables, on = "Date")
prices2013_brent_weather
# Out:
#            Energía final MWh Mercado diario €/MWh Mercado intradiario €/MWh  \
# Date
# 2013-06-01        647854.785                58.01                         0
# 2013-07-01        707896.584                63.42                     -0.18
# 2013-08-01        792239.818                   69                      0.08
# 2013-09-01        813192.864                67.43                      0.05
# 2013-10-01        821426.583                66.12                      0.09
# ...                      ...                  ...                       ...
# 2013-12-27        663171.045                15.39                         0
# 2013-12-28         672714.85                23.98                      0.01
# 2013-12-29        634045.486                42.83                     -0.13
# 2013-12-30        634951.745                47.39                     -0.57
# 2013-12-31        606765.004                25.26                     -0.15
#
# ...

# %% [markdown]
# It seems that we don't have weather data for all days of the year (now looking at 2013 only)

# %%
weather_variables_2013 = weather_variables.loc['2013-01-01':'2013-12-31']
weather_variables_2013
# Out:
#                  Tmax       Tmin       Tmed       Vmax     TPrec      Altura
# Date
# 2013-05-07  26.024410  13.555936  19.797901  17.838921  2.095502  388.574585
# 2013-05-08  25.336803  14.118225  19.728336  15.444501  0.565097  388.574585
# 2013-05-09  23.381573  13.126208  18.251265  15.949620  1.760222  377.103973
# 2013-05-10  22.928568  12.023178  17.480787  16.672112  0.249773  377.103973
# 2013-05-11  22.691177  10.655726  16.671419  15.552441  0.003383  377.103973
# ...               ...        ...        ...        ...       ...         ...
# 2013-12-27  14.972183   6.814744  10.901595  20.926922  2.394948  385.403412
# 2013-12-28  13.374936   4.452909   8.915764  24.365299  2.491523  385.403412
# 2013-12-29  11.291446   2.104122   6.691592  17.161993  0.205239  385.403412
# 2013-12-30  12.021042   1.110683   6.578516  15.843420  1.099209  385.403412
# 2013-12-31  12.720055   2.847992   7.781052  16.840603  1.675617  385.403412
#
# [238 rows x 6 columns]

# %%
new_index_2013 = pd.date_range(start='2013-01-01', end='2013-12-31')

# %%
weather_variables_2013 = weather_variables_2013.reindex(new_index_2013)
weather_variables_2013
# Out:
#                  Tmax      Tmin       Tmed       Vmax     TPrec      Altura
# 2013-01-01        NaN       NaN        NaN        NaN       NaN         NaN
# 2013-01-02        NaN       NaN        NaN        NaN       NaN         NaN
# 2013-01-03        NaN       NaN        NaN        NaN       NaN         NaN
# 2013-01-04        NaN       NaN        NaN        NaN       NaN         NaN
# 2013-01-05        NaN       NaN        NaN        NaN       NaN         NaN
# ...               ...       ...        ...        ...       ...         ...
# 2013-12-27  14.972183  6.814744  10.901595  20.926922  2.394948  385.403412
# 2013-12-28  13.374936  4.452909   8.915764  24.365299  2.491523  385.403412
# 2013-12-29  11.291446  2.104122   6.691592  17.161993  0.205239  385.403412
# 2013-12-30  12.021042  1.110683   6.578516  15.843420  1.099209  385.403412
# 2013-12-31  12.720055  2.847992   7.781052  16.840603  1.675617  385.403412
#
# [365 rows x 6 columns]

# %%
weather_variables_2013["Tmax"].isnull().sum()
# Out:
# 127

# %%
weather_variables_2013.isnull().values.any()
# Out:
# True

# %%
pd.options.display.max_rows=365
nan_rows2013 = weather_variables_2013[weather_variables_2013.isnull().any(1)]
nan_rows2013
# Out:
#             Tmax  Tmin  Tmed  Vmax  TPrec  Altura
# 2013-01-01   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-02   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-03   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-04   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-05   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-06   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-07   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-08   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-09   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-10   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-11   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-12   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-13   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-14   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-15   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-16   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-17   NaN   NaN   NaN   NaN    NaN     NaN
# 2013-01-18   NaN   NaN   NaN   NaN    NaN     NaN
# ...

# %% [markdown]
# So it looks like we're missing Jan-May from 2013 (this was already specified in the database)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prices2013_brent_weather
# Out:
#            Energía final MWh Mercado diario €/MWh Mercado intradiario €/MWh  \
# Date
# 2013-06-01        647854.785                58.01                         0
# 2013-07-01        707896.584                63.42                     -0.18
# 2013-08-01        792239.818                   69                      0.08
# 2013-09-01        813192.864                67.43                      0.05
# 2013-10-01        821426.583                66.12                      0.09
# 2013-11-01        798185.741                72.41                     -0.07
# 2013-12-01        740278.669                   54                      0.03
# 2013-06-02        828424.928                20.32                      0.12
# 2013-07-02        815307.458                42.85                      -0.2
# 2013-08-02         798919.17                37.96                      0.03
# 2013-09-02        737447.516                 50.7                      -0.3
# ...
